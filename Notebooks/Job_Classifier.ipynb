# %% [markdown]
# # Job Postings EDA

# %% [markdown]
# ## Importing Drive folder

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Project_CL
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Project_CL

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = pd.read_csv("fake_job_postings.csv")
df
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
# Job_id should be categorical

df["job_id"] = df["job_id"].astype('object')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  object
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
#checking salary range
df[df["salary_range"].notnull()]
# Out:
#       job_id                                              title  \
# 6          7                              Head of Content (m/f)
# 10        11  ASP.net Developer Job opportunity at United St...
# 15        16                         VP of Sales - Vault Dragon
# 23        24  Vice President, Sales and Sponsorship (Busines...
# 31        32                   Software Applications Specialist
# ...      ...                                                ...
# 17844  17845             Sr. Scm Web Development Technical Lead
# 17849  17850                             Communication Designer
# 17865  17866  Portfolio Development Associate - Paris & rest...
# 17867  17868                                   Admin Assistant
# 17874  17875                               JavaScript Developer
#
#                     location          department   salary_range  \
# 6             DE, BE, Berlin          ANDROIDPIT    20000-28000
# 10       US, NJ, Jersey City                 NaN  100000-120000
# ...

# %%
df.describe()
# Out:
#        telecommuting  has_company_logo  has_questions    fraudulent
# count   17880.000000      17880.000000   17880.000000  17880.000000
# mean        0.042897          0.795302       0.491723      0.048434
# std         0.202631          0.403492       0.499945      0.214688
# min         0.000000          0.000000       0.000000      0.000000
# 25%         0.000000          1.000000       0.000000      0.000000
# 50%         0.000000          1.000000       0.000000      0.000000
# 75%         0.000000          1.000000       1.000000      0.000000
# max         1.000000          1.000000       1.000000      1.000000

# %%
# Distribution of the target variable 'fraudulent'
target_distribution = df['fraudulent'].value_counts(normalize=True) * 100

target_distribution
# Out:
# fraudulent
# 0    95.1566
# 1     4.8434
# Name: proportion, dtype: float64

# %%
# Exploring Categorical Variables - Checking the number of unique values in some categorical columns
unique_job_titles = df['title'].nunique()
unique_locations = df['location'].nunique()
unique_departments = df['department'].nunique()

# Text Data Overview - Checking the presence of text data by summarizing the average length of strings
avg_len_company_profile = df['company_profile'].dropna().apply(len).mean()
avg_len_description = df['description'].dropna().apply(len).mean()
avg_len_requirements = df['requirements'].dropna().apply(len).mean()
avg_len_benefits = df['benefits'].dropna().apply(len).mean()

(unique_job_titles, unique_locations, unique_departments,
 avg_len_company_profile, avg_len_description, avg_len_requirements, avg_len_benefits)
# Out:
# (11231,
#  3105,
#  1337,
#  761.8527312654405,
#  1218.0725432071144,
#  694.9133298208641,
#  350.1176415448069)

# %% [markdown]
# ### Missing Data

# %%
# pct of nulls
df.isnull().sum()/len(df) * 100
# Out:
# job_id                  0.000000
# title                   0.000000
# location                1.935123
# department             64.580537
# salary_range           83.959732
# company_profile        18.501119
# description             0.005593
# requirements           15.078300
# benefits               40.335570
# telecommuting           0.000000
# has_company_logo        0.000000
# has_questions           0.000000
# employment_type        19.412752
# required_experience    39.429530
# required_education     45.329978
# industry               27.421700
# function               36.101790
# fraudulent              0.000000
# dtype: float64

# %%
null_percentage = df.isnull().mean() * 100

# Order the percentages in descending order
null_percentage_sorted = null_percentage.sort_values(ascending=False)

# Plotting the sorted data
plt.figure(figsize=(10, 6))
null_percentage_sorted.plot(kind='bar')
plt.title('Percentage of Nulls per Column in Descending Order')
plt.xlabel('Columns')
plt.ylabel('Percentage of Nulls')
plt.grid(axis='y')

# Display the plot
plt.show()

# %% [markdown]
# Since the null porcentage in the salary range is to high, I will remove the column. The idea was to split the range between min and max, but 86% of the column are null values, so better being removed.
#
# Department is also high, but I will leave it just to check how relevant it is in the analysis

# %%
df = df.drop(columns='salary_range', axis=1)
df.head()
# Out:
#   job_id                                      title            location  \
# 0      1                           Marketing Intern    US, NY, New York
# 1      2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2      3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3      4          Account Executive - Washington DC  US, DC, Washington
# 4      5                        Bill Review Manager  US, FL, Fort Worth
#
#   department                                    company_profile  \
# 0  Marketing  We're Food52, and we've created a groundbreaki...
# 1    Success  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN  Valor Services provides Workforce Solutions th...
# 3      Sales  Our passion for improving quality of life thro...
# 4        NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# ...

# %% [markdown]
# Location is divided in Country, State, City. Lets divide it

# %%
df[['Country', 'State', 'City']] = df['location'].str.split(', ', expand=True).reindex(columns=range(3), fill_value=np.nan)
df.head()
# Out:
#   job_id                                      title            location  \
# 0      1                           Marketing Intern    US, NY, New York
# 1      2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2      3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3      4          Account Executive - Washington DC  US, DC, Washington
# 4      5                        Bill Review Manager  US, FL, Fort Worth
#
#   department                                    company_profile  \
# 0  Marketing  We're Food52, and we've created a groundbreaki...
# 1    Success  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN  Valor Services provides Workforce Solutions th...
# 3      Sales  Our passion for improving quality of life thro...
# 4        NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# ...

# %%
df.groupby('required_experience').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.groupby('required_education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.groupby('industry').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.groupby('function').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), figsize=(15, 10))
# Out:
# <Axes: ylabel='function'>

# %%
df.groupby('Country').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.groupby('State').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(6, 4))
df['fraudulent'].value_counts().plot(kind='bar')
plt.title('Distribution of Fraudulent')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# So we have an imbalance dataset, we should try to balance it or analyze a way to continue with our classification model

# %% [markdown]
# DATA ENGINEERING AND CLEANING

# %%
# Selecting only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plotting the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap with Target Column "Fraudulent"')
plt.show()

# %%
df.head()
# Out:
#   job_id                                      title            location  \
# 0      1                           Marketing Intern    US, NY, New York
# 1      2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2      3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3      4          Account Executive - Washington DC  US, DC, Washington
# 4      5                        Bill Review Manager  US, FL, Fort Worth
#
#   department                                    company_profile  \
# 0  Marketing  We're Food52, and we've created a groundbreaki...
# 1    Success  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN  Valor Services provides Workforce Solutions th...
# 3      Sales  Our passion for improving quality of life thro...
# 4        NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# ...

# %%
plt.figure(figsize=(6, 4))
df['fraudulent'].value_counts().plot(kind='bar')
plt.title('Distribution of Fraudulent')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df.fillna(' ',inplace=True)

# %%
df.isnull().sum()
# Out:
# job_id                 0
# title                  0
# location               0
# department             0
# company_profile        0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# Country                0
# State                  0
# City                   0
# dtype: int64

# %%
df['combined_text'] = df[['title', 'location','company_profile','description','requirements','benefits','employment_type','required_experience','required_education','industry','function','department']].apply(lambda x: ' '.join(x), axis=1)

# %%
df.drop(columns=['title',
                 'location',
                 'company_profile',
                 'description',
                 'requirements',
                 'benefits',
                 'employment_type',
                 'required_experience',
                 'required_education',
                 'industry',
                 'function',
                 'department',
                 'telecommuting',
                 'has_questions',
                 'job_id'
                 ], inplace=True)

# %%
df.drop(columns= ['Country','State','City'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    has_company_logo  fraudulent  \
# 0                 1           0
# 1                 1           0
# 2                 1           0
# 3                 1           0
# 4                 1           0
#
#                                        combined_text
# 0  Marketing Intern US, NY, New York We're Food52...
# 1  Customer Service - Cloud Video Production NZ, ...
# 2  Commissioning Machinery Assistant (CMA) US, IA...
# 3  Account Executive - Washington DC US, DC, Wash...
# 4  Bill Review Manager US, FL, Fort Worth SpotSou...

# %%
fake=df[df['fraudulent']==1]['combined_text']
real=df[df['fraudulent']==0]['combined_text']

# %%
import spacy
from wordcloud import WordCloud
from spacy.lang.en.stop_words import STOP_WORDS

STOPWORDS = spacy.lang.en.stop_words.STOP_WORDS

wordcloud = WordCloud(min_font_size=4,width=500, height=200, background_color='white',stopwords=STOPWORDS).generate(' '.join(fake))
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud = WordCloud(min_font_size=4,width=500, height=200, background_color='white',stopwords=STOPWORDS).generate(' '.join(real))
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')

def clean_text(text):

    text = text.lower()
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text)
    tokens = nltk.word_tokenize(text)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    cleaned_text = ' '.join(tokens)

    return cleaned_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['combined_text']=df['combined_text'].apply(clean_text)

# %%
df.head()
# Out:
#    has_company_logo  fraudulent  \
# 0                 1           0
# 1                 1           0
# 2                 1           0
# 3                 1           0
# 4                 1           0
#
#                                        combined_text
# 0  marketing intern us ny new york food52 created...
# 1  customer service cloud video production nz auc...
# 2  commissioning machinery assistant cma us ia we...
# 3  account executive washington dc us dc washingt...
# 4  bill review manager us fl fort worth spotsourc...

# %% [markdown]
# NORMALIZATION

# %%
nlp = spacy.load("en_core_web_sm")

def normalize_text(text):
    # Tokenize the text and apply lemmatization
    doc = nlp(text)
    normalized_words = [token.lemma_ for token in doc]
    normalized_text = ' '.join(normalized_words)
    return normalized_text

# %%
df['combined_text']=df['combined_text'].apply(normalize_text)

# %%
nltk.download('averaged_perceptron_tagger')
import pickle
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.sparse import hstack,csr_matrix

text_columns = ['combined_text']

df['pos_features'] = df[text_columns].apply(lambda x: nltk.pos_tag(word_tokenize(x[0])), axis=1)
df['pos_features'] = df['pos_features'].apply(lambda tags: ' '.join(tag[1] for tag in tags))

X_train = df.drop('fraudulent', axis=1)
y_train = df['fraudulent']

vectorizer = CountVectorizer(ngram_range=(1, 2))
text_matrix_train = vectorizer.fit_transform(X_train['combined_text'])
pos_matrix_train = vectorizer.transform(X_train['pos_features'])
combined_matrix_train = hstack([text_matrix_train, pos_matrix_train])

with open('countvectorizer.pkl', 'wb') as file:
    pickle.dump(vectorizer, file)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from scipy.sparse import hstack

# Separate features and target variable
X_text = df['combined_text']
X_numeric = df.drop(['fraudulent', 'combined_text'], axis=1)
y = df['fraudulent']

# Handle missing values if any
X_numeric.fillna(0, inplace=True)  # Fill missing values with 0 (you can use other strategies)

# Check for and encode categorical variables if present
# For simplicity, let's assume all non-numeric columns are categorical
categorical_columns = X_numeric.select_dtypes(include=['object']).columns
X_numeric_encoded = pd.get_dummies(X_numeric, columns=categorical_columns)

# Convert numerical features to float
X_numeric_encoded = X_numeric_encoded.astype(float)

# Split the data into training and testing sets
X_train_text, X_test_text, X_train_numeric, X_test_numeric, y_train, y_test = train_test_split(X_text, X_numeric_encoded, y, test_size=0.2, random_state=42)

# Apply TF-IDF vectorization to convert text data into numerical vectors
tfidf = TfidfVectorizer(max_features=50000)
X_train_tfidf = tfidf.fit_transform(X_train_text)
X_test_tfidf = tfidf.transform(X_test_text)

# Combine TF-IDF transformed text data with numerical data
X_train = hstack((X_train_tfidf, X_train_numeric.values))
X_test = hstack((X_test_tfidf, X_test_numeric.values))

# Apply SMOTE to balance the training data equally
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
print("Shape of resampled X_train:", X_train_resampled.shape)
print("Shape of resampled y_train:", y_train_resampled.shape)
# Out:
# Shape of resampled X_train: (27238, 21382)
# Shape of resampled y_train: (27238,)

# %% [markdown]
# ## Models
#
# For the model we have to make feature engineering, this will be changing the categorical (object) columns into one hote encoding or label encoding, this will be just checking how it will work for the model. For now, the correlation heat map is only showing correlation with the numerical columns, and we need to analyze if the other columns have something to do with our model.
#
# We can model right now and then make the feature engineering. Will be creating a base line model.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Define and initialize the Random Forest Classifier model
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training data
random_forest_model.fit(X_train_resampled, y_train_resampled)

# Predict on the test data
y_pred = random_forest_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report
print(classification_report(y_test, y_pred))

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Fraudulent', 'Fraudulent'],
            yticklabels=['Non-Fraudulent', 'Fraudulent'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.9815436241610739
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3395
#            1       0.99      0.64      0.78       181
#
#     accuracy                           0.98      3576
#    macro avg       0.99      0.82      0.88      3576
# weighted avg       0.98      0.98      0.98      3576

# %%
from sklearn.svm import SVC

# Define and initialize the Support Vector Classifier (SVC) model
svc_model = SVC(kernel='linear', random_state=42)

# Train the model on the training data
svc_model.fit(X_train_resampled, y_train_resampled)

# Predict on the test data
y_pred_svc = svc_model.predict(X_test)

# Evaluate the model
accuracy_svc = accuracy_score(y_test, y_pred_svc)
print("Accuracy:", accuracy_svc)

# Print classification report
print(classification_report(y_test, y_pred_svc))

# Calculate confusion matrix
conf_matrix_svc = confusion_matrix(y_test, y_pred_svc)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_svc, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Fraudulent', 'Fraudulent'],
            yticklabels=['Non-Fraudulent', 'Fraudulent'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.985178970917226
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3395
#            1       0.98      0.72      0.83       181
#
#     accuracy                           0.99      3576
#    macro avg       0.98      0.86      0.91      3576
# weighted avg       0.99      0.99      0.98      3576

# %%
from sklearn.linear_model import LogisticRegression

# Define and initialize the Logistic Regression model
logistic_regression_model = LogisticRegression(random_state=42)

# Train the model on the training data
logistic_regression_model.fit(X_train_resampled, y_train_resampled)

# Predict on the test data
y_pred_logistic = logistic_regression_model.predict(X_test)

# Evaluate the model
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
print("Accuracy:", accuracy_logistic)

# Print classification report
print(classification_report(y_test, y_pred_logistic))

# Calculate confusion matrix
conf_matrix_logistic = confusion_matrix(y_test, y_pred_logistic)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_logistic, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Fraudulent', 'Fraudulent'],
            yticklabels=['Non-Fraudulent', 'Fraudulent'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.9767897091722595
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      3395
#            1       0.74      0.83      0.78       181
#
#     accuracy                           0.98      3576
#    macro avg       0.87      0.91      0.89      3576
# weighted avg       0.98      0.98      0.98      3576

# %%
from sklearn.naive_bayes import MultinomialNB

# Define and initialize the Multinomial Naive Bayes model
mnb_model = MultinomialNB()

# Train the model on the resampled training data
mnb_model.fit(X_train_resampled, y_train_resampled)

# Predict on the test data
y_pred_mnb = mnb_model.predict(X_test)

# Evaluate the model
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print("Accuracy:", accuracy_mnb)

# Print classification report
print(classification_report(y_test, y_pred_mnb))

# Calculate confusion matrix
conf_matrix_mnb = confusion_matrix(y_test, y_pred_mnb)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_mnb, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Fraudulent', 'Fraudulent'],
            yticklabels=['Non-Fraudulent', 'Fraudulent'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.9395973154362416
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97      3395
#            1       0.45      0.88      0.60       181
#
#     accuracy                           0.94      3576
#    macro avg       0.72      0.91      0.78      3576
# weighted avg       0.97      0.94      0.95      3576
